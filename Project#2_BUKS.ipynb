# %%
import matplotlib.pyplot as plt
import pylab

# %%
k1m = 0.001    #variant
#k1m = 0.005
#k1m = 0.01
#k1m = 0.015
#k1m = 0.02
k3 = 0.0032
k2 = 2
k3m= 0.002
x = [round((i+0.001)/1000,3) for i in range(1000)]
y = [k3/k3m*x[i] for i in range(1000)]
z = [1-x[i]-y[i] for i in range(1000)]
k1 = [(k1m*x[i]+k2*x[i]*(z[i])**2)/z[i] for i in range(1000)]
a11 = [-k1[i]-k1m-k3-k2+4*k2*x[i]-3*k2*(x[i])**2+2*k2*y[i]-4*k2*y[i]*x[i]-k2*(y[i])**2 for i in range(1000)]
a12 = [-k1[i]+k3m+2*k2*x[i]-2*k2*(x[i])**2-2*k2*x[i]*y[i] for i in range(1000)]
a21 = k3 
a22 = -k3m
sp = [a11[i]+a22 for i in range(1000)]
determ = [a11[i]*a22-a12[i]*a21 for i in range(1000)]
DI = [sp[i]**2-4*determ[i] for i in range(1000)]
index = 1
yh = []
xh = []
k1h = []
ysn = []
xsn = []
k1sn = []
ydi = []
xdi = []
k1di = []
while index < 1000:
    if sp[index]*sp[index-1] <= 0:
        yh.append(y[index])
        xh.append(x[index])
        k1h.append(k1[index])
    if determ[index]*determ[index-1] <= 0:
        ysn.append(y[index])
        xsn.append(x[index])
        k1sn.append(k1[index])
    if DI[index]*DI[index-1] <= 0:
        ydi.append(y[index])
        xdi.append(x[index])
        k1di.append(k1[index])
    index += 1
print(len(xh))
print(len(xsn))
print(len(xdi))
mh = len(xh)
msn = len(xsn)
mdi = len(xdi)
fig = plt.figure()
plt.plot(k1, x, label = u'x')
plt.plot(k1, y, label = u'y', linestyle='--')
plt.plot(k1h,yh, label = u'hopf(y(k1))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k1sn,ysn, label = u'saddle-node(y(k1))', linestyle = 'None', marker='d')
plt.plot(k1h,xh, label = u'hopf(x(k1))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k1sn,xsn, label = u'saddle-node(x(k1))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('y',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0,1))
plt.legend()
plt.grid(True)
plt.show()
fig1 = plt.figure()
plt.plot(k1, y, label = u'y', linestyle='--')
plt.plot(k1h,yh, label = u'hopf(y(k1))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k1sn,ysn, label = u'saddle-node(y(k1))', linestyle = 'None', marker='d')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('y',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.58,0.65))
plt.legend()
plt.grid(True)
plt.show()
fig2 = plt.figure()
plt.plot(k1, y, label = u'y', linestyle='--')
plt.plot(k1h,yh, label = u'hopf(y(k1))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k1sn,ysn, label = u'saddle-node(y(k1))', linestyle = 'None', marker='d')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('x',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.3,0.5))
plt.legend()
plt.grid(True)
plt.show()
plt.plot(k1, x, label = u'x')
plt.plot(k1h,xh, label = u'hopf(x(k1))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k1sn,xsn, label = u'saddle-node(x(k1))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('x',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.37,0.4))
plt.legend()
plt.grid(True)
plt.show()
plt.plot(k1, x, label = u'x')
plt.plot(k1h,xh, label = u'hopf(x(k1))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k1sn,xsn, label = u'saddle-node(x(k1))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('x',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0,0.3))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 4
# 4
# 0

# %%
#k1m = 0.001    #variant
#k1m = 0.005
#k1m = 0.01
#k1m = 0.015
k1m = 0.02
k3 = 0.0032
k2 = 2
k3m= 0.002
x = [round((i+0.001)/1000,3) for i in range(1000)]
y = [k3/k3m*x[i] for i in range(1000)]
z = [1-x[i]-y[i] for i in range(1000)]
k1 = [(k1m*x[i]+k2*x[i]*(z[i])**2)/z[i] for i in range(1000)]
a11 = [-k1[i]-k1m-k3-k2+4*k2*x[i]-3*k2*(x[i])**2+2*k2*y[i]-4*k2*y[i]*x[i]-k2*(y[i])**2 for i in range(1000)]
a12 = [-k1[i]+k3m+2*k2*x[i]-2*k2*(x[i])**2-2*k2*x[i]*y[i] for i in range(1000)]
a21 = k3 
a22 = -k3m
sp = [a11[i]+a22 for i in range(1000)]
determ = [a11[i]*a22-a12[i]*a21 for i in range(1000)]
DI = [sp[i]**2-4*determ[i] for i in range(1000)]
index = 1
yh = []
xh = []
k1h = []
ysn = []
xsn = []
k1sn = []
ydi = []
xdi = []
k1di = []
while index < 1000:
    if sp[index]*sp[index-1] <= 0:
        yh.append(y[index])
        xh.append(x[index])
        k1h.append(k1[index])
    if determ[index]*determ[index-1] <= 0:
        ysn.append(y[index])
        xsn.append(x[index])
        k1sn.append(k1[index])
    if DI[index]*DI[index-1] <= 0:
        ydi.append(y[index])
        xdi.append(x[index])
        k1di.append(k1[index])
    index += 1
print(len(xh))
print(len(xsn))
print(len(xdi))
mh = len(xh)
msn = len(xsn)
mdi = len(xdi)
fig = plt.figure()
plt.plot(k1, x, label = u'x')
plt.plot(k1, y, label = u'y', linestyle='--')
plt.plot(k1h,yh, label = u'hopf(y(k1))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k1sn,ysn, label = u'saddle-node(y(k1))', linestyle = 'None', marker='d')
plt.plot(k1h,xh, label = u'hopf(x(k1))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k1sn,xsn, label = u'saddle-node(x(k1))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('y',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0,1))
plt.legend()
plt.grid(True)
plt.show()
fig1 = plt.figure()
plt.plot(k1, y, label = u'y', linestyle='--')
plt.plot(k1h,yh, label = u'hopf(y(k1))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k1sn,ysn, label = u'saddle-node(y(k1))', linestyle = 'None', marker='d')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('y',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.3,0.7))
plt.legend()
plt.grid(True)
plt.show()
plt.plot(k1, x, label = u'x')
plt.plot(k1h,xh, label = u'hopf(x(k1))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k1sn,xsn, label = u'saddle-node(x(k1))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('x',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.33,0.44))
plt.legend()
plt.grid(True)
plt.show()
plt.plot(k1, x, label = u'x')
plt.plot(k1h,xh, label = u'hopf(x(k1))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k1sn,xsn, label = u'saddle-node(x(k1))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('x',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.15,0.3))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 2
# 4
# 0

# %%
k1m =  0.01
k3 = 0.0032
k2 = 2
k3m = 0.0005 #variant
#k3m = 0.001
#k3m = 0.002
#k3m = 0.003
#k3m = 0.004 
x = [round((i+0.001)/1000,3) for i in range(1000)]
y = [k3/k3m*x[i] for i in range(1000)]
z = [1-x[i]-y[i] for i in range(1000)]
k1 = [(k1m*x[i]+k2*x[i]*(z[i])**2)/z[i] for i in range(1000)]
a11 = [-k1[i]-k1m-k3-k2+4*k2*x[i]-3*k2*(x[i])**2+2*k2*y[i]-4*k2*y[i]*x[i]-k2*(y[i])**2 for i in range(1000)]
a12 = [-k1[i]+k3m+2*k2*x[i]-2*k2*(x[i])**2-2*k2*x[i]*y[i] for i in range(1000)]
a21 = k3 
a22 = -k3m
sp = [a11[i]+a22 for i in range(1000)]
determ = [a11[i]*a22-a12[i]*a21 for i in range(1000)]
DI = [sp[i]**2-4*determ[i] for i in range(1000)]
index = 1
yh = []
xh = []
k1h = []
ysn = []
xsn = []
k1sn = []
ydi = []
xdi = []
k1di = []
while index < 1000:
    if sp[index]*sp[index-1] <= 0:
        yh.append(y[index])
        xh.append(x[index])
        k1h.append(k1[index])
    if determ[index]*determ[index-1] <= 0:
        ysn.append(y[index])
        xsn.append(x[index])
        k1sn.append(k1[index])
    if DI[index]*DI[index-1] <= 0:
        ydi.append(y[index])
        xdi.append(x[index])
        k1di.append(k1[index])
    index += 1
print(len(xh))
print(len(xsn))
print(len(xdi))
mh = len(xh)
msn = len(xsn)
mdi = len(xdi)
fig = plt.figure()
plt.plot(k1, x, label = u'x')
plt.plot(k1, y, label = u'y', linestyle='--')
plt.plot(k1h,yh, label = u'hopf(y(k1))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k1sn,ysn, label = u'saddle-node(y(k1))', linestyle = 'None', marker='d')
plt.plot(k1h,xh, label = u'hopf(x(k1))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k1sn,xsn, label = u'saddle-node(x(k1))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('y',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0,1))
plt.legend()
plt.grid(True)
plt.show()
fig1 = plt.figure()
plt.plot(k1, y, label = u'y', linestyle='--')
plt.plot(k1h,yh, label = u'hopf(y(k1))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k1sn,ysn, label = u'saddle-node(y(k1))', linestyle = 'None', marker='d')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('y',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.75,1))
plt.legend()
plt.grid(True)
plt.show()
fig2 = plt.figure()
plt.plot(k1, y, label = u'y', linestyle='--')
plt.plot(k1h,yh, label = u'hopf(y(k1))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k1sn,ysn, label = u'saddle-node(y(k1))', linestyle = 'None', marker='d')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('x',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.3,0.5))
plt.legend()
plt.grid(True)
plt.show()
plt.plot(k1, x, label = u'x')
plt.plot(k1h,xh, label = u'hopf(x(k1))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k1sn,xsn, label = u'saddle-node(x(k1))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('x',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.05,0.16))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 2
# 4
# 0

# %%
k1m =  0.01
k3 = 0.0032
k2 = 2
#k3m = 0.0005 #variant
#k3m = 0.001
#k3m = 0.002
#k3m = 0.003
k3m = 0.004 
x = [round((i+0.001)/1000,3) for i in range(1000)]
y = [k3/k3m*x[i] for i in range(1000)]
z = [1-x[i]-y[i] for i in range(1000)]
k1 = [(k1m*x[i]+k2*x[i]*(z[i])**2)/z[i] for i in range(1000)]
a11 = [-k1[i]-k1m-k3-k2+4*k2*x[i]-3*k2*(x[i])**2+2*k2*y[i]-4*k2*y[i]*x[i]-k2*(y[i])**2 for i in range(1000)]
a12 = [-k1[i]+k3m+2*k2*x[i]-2*k2*(x[i])**2-2*k2*x[i]*y[i] for i in range(1000)]
a21 = k3 
a22 = -k3m
sp = [a11[i]+a22 for i in range(1000)]
determ = [a11[i]*a22-a12[i]*a21 for i in range(1000)]
DI = [sp[i]**2-4*determ[i] for i in range(1000)]
index = 1
yh = []
xh = []
k1h = []
ysn = []
xsn = []
k1sn = []
ydi = []
xdi = []
k1di = []
while index < 1000:
    if sp[index]*sp[index-1] <= 0:
        yh.append(y[index])
        xh.append(x[index])
        k1h.append(k1[index])
    if determ[index]*determ[index-1] <= 0:
        ysn.append(y[index])
        xsn.append(x[index])
        k1sn.append(k1[index])
    if DI[index]*DI[index-1] <= 0:
        ydi.append(y[index])
        xdi.append(x[index])
        k1di.append(k1[index])
    index += 1
print(len(xh))
print(len(xsn))
print(len(xdi))
mh = len(xh)
msn = len(xsn)
mdi = len(xdi)
fig = plt.figure()
plt.plot(k1, x, label = u'x')
plt.plot(k1, y, label = u'y', linestyle='--')
plt.plot(k1h,yh, label = u'hopf(y(k1))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k1sn,ysn, label = u'saddle-node(y(k1))', linestyle = 'None', marker='d')
plt.plot(k1h,xh, label = u'hopf(x(k1))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k1sn,xsn, label = u'saddle-node(x(k1))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('y',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0,1))
plt.legend()
plt.grid(True)
plt.show()
fig1 = plt.figure()
plt.plot(k1, y, label = u'y', linestyle='--')
plt.plot(k1h,yh, label = u'hopf(y(k1))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k1sn,ysn, label = u'saddle-node(y(k1))', linestyle = 'None', marker='d')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('y',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.2,0.5))
plt.legend()
plt.grid(True)
plt.show()
plt.plot(k1, x, label = u'x')
plt.plot(k1h,xh, label = u'hopf(x(k1))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k1sn,xsn, label = u'saddle-node(x(k1))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k1',fontsize=16)
plt.ylabel('x',fontsize=14)
plt.xlabel('k1',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.25,0.6))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 4
# 4
# 0

# %%
k1m = 0.001    #variant
#k1m = 0.005
#k1m = 0.01
#k1m = 0.015
#k1m = 0.02
k3 = 0.0032
k1 = 1
k3m= 0.002
x = [round((i+0.001)/1000+0.001,3) for i in range(1000)]
y = [k3/k3m*x[i] for i in range(1000)]
z = [1-x[i]-y[i] for i in range(1000)]
k2 = [(k1*z[i]-k1m*x[i])/(x[i]*(z[i])**2) for i in range(1000)]
a11 = [-k1-k1m-k3-k2[i]+4*k2[i]*x[i]-3*k2[i]*(x[i])**2+2*k2[i]*y[i]-4*k2[i]*y[i]*x[i]-k2[i]*(y[i])**2 for i in range(1000)]
a12 = [-k1+k3m+2*k2[i]*x[i]-2*k2[i]*(x[i])**2-2*k2[i]*x[i]*y[i] for i in range(1000)]
a21 = k3 
a22 = -k3m
sp = [a11[i]+a22 for i in range(1000)]
determ = [a11[i]*a22-a12[i]*a21 for i in range(1000)]
DI = [sp[i]**2-4*determ[i] for i in range(1000)]
index = 1
yh = []
xh = []
k2h = []
ysn = []
xsn = []
k2sn = []
ydi = []
xdi = []
k2di = []
while index < 1000:
    if sp[index]*sp[index-1] <= 0:
        yh.append(y[index])
        xh.append(x[index])
        k2h.append(k2[index])
    if determ[index]*determ[index-1] <= 0:
        ysn.append(y[index])
        xsn.append(x[index])
        k2sn.append(k2[index])
    if DI[index]*DI[index-1] <= 0:
        ydi.append(y[index])
        xdi.append(x[index])
        k2di.append(k2[index])
    index += 1
print(len(xh))
print(len(xsn))
print(len(xdi))
mh = len(xh)
msn = len(xsn)
mdi = len(xdi)
fig = plt.figure()
plt.plot(k2, x, label = u'x')
plt.plot(k2, y, label = u'y', linestyle='--')
plt.plot(k2h,yh, label = u'hopf(y(k2))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k2sn,ysn, label = u'saddle-node(y(k2))', linestyle = 'None', marker='d')
plt.plot(k2h,xh, label = u'hopf(x(k1))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k2sn,xsn, label = u'saddle-node(x(k2))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k2',fontsize=16)
plt.ylabel('x, y',fontsize=14)
plt.xlabel('k2',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0,1))
plt.legend()
plt.grid(True)
plt.show()
fig1 = plt.figure()
plt.plot(k2, y, label = u'y', linestyle='--')
plt.plot(k2h,yh, label = u'hopf(y(k2))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k2sn,ysn, label = u'saddle-node(y(k2))', linestyle = 'None', marker='d')
plt.title('Dependence on Parameter k2',fontsize=16)
plt.ylabel('y',fontsize=14)
plt.xlabel('k2',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.2,0.7))
plt.legend()
plt.grid(True)
plt.show()
plt.plot(k2, x, label = u'x')
plt.plot(k2h,xh, label = u'hopf(x(k2))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k2sn,xsn, label = u'saddle-node(x(k2))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k2',fontsize=16)
plt.ylabel('x',fontsize=14)
plt.xlabel('k2',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.18,0.5))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 1
# 1
# 0

# %%
#k1m = 0.001    #variant
#k1m = 0.005
#k1m = 0.01
#k1m = 0.015
k1m = 0.02
k3 = 0.0032
k1 = 1
k3m= 0.002
x = [round((i+0.001)/1000+0.001,3) for i in range(1000)]
y = [k3/k3m*x[i] for i in range(1000)]
z = [1-x[i]-y[i] for i in range(1000)]
k2 = [(k1*z[i]-k1m*x[i])/(x[i]*(z[i])**2) for i in range(1000)]
a11 = [-k1-k1m-k3-k2[i]+4*k2[i]*x[i]-3*k2[i]*(x[i])**2+2*k2[i]*y[i]-4*k2[i]*y[i]*x[i]-k2[i]*(y[i])**2 for i in range(1000)]
a12 = [-k1+k3m+2*k2[i]*x[i]-2*k2[i]*(x[i])**2-2*k2[i]*x[i]*y[i] for i in range(1000)]
a21 = k3 
a22 = -k3m
sp = [a11[i]+a22 for i in range(1000)]
determ = [a11[i]*a22-a12[i]*a21 for i in range(1000)]
DI = [sp[i]**2-4*determ[i] for i in range(1000)]
index = 1
yh = []
xh = []
k2h = []
ysn = []
xsn = []
k2sn = []
ydi = []
xdi = []
k2di = []
while index < 1000:
    if sp[index]*sp[index-1] <= 0:
        yh.append(y[index])
        xh.append(x[index])
        k2h.append(k2[index])
    if determ[index]*determ[index-1] <= 0:
        ysn.append(y[index])
        xsn.append(x[index])
        k2sn.append(k2[index])
    if DI[index]*DI[index-1] <= 0:
        ydi.append(y[index])
        xdi.append(x[index])
        k2di.append(k2[index])
    index += 1
print(len(xh))
print(len(xsn))
print(len(xdi))
mh = len(xh)
msn = len(xsn)
mdi = len(xdi)
fig = plt.figure()
plt.plot(k2, x, label = u'x')
plt.plot(k2, y, label = u'y', linestyle='--')
plt.plot(k2h,yh, label = u'hopf(y(k2))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k2sn,ysn, label = u'saddle-node(y(k2))', linestyle = 'None', marker='d')
plt.plot(k2h,xh, label = u'hopf(x(k1))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k2sn,xsn, label = u'saddle-node(x(k2))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k2',fontsize=16)
plt.ylabel('x, y',fontsize=14)
plt.xlabel('k2',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0,1))
plt.legend()
plt.grid(True)
plt.show()
fig1 = plt.figure()
plt.plot(k2, y, label = u'y', linestyle='--')
plt.plot(k2h,yh, label = u'hopf(y(k2))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k2sn,ysn, label = u'saddle-node(y(k2))', linestyle = 'None', marker='d')
plt.title('Dependence on Parameter k2',fontsize=16)
plt.ylabel('y',fontsize=14)
plt.xlabel('k2',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.3,0.7))
plt.legend()
plt.grid(True)
plt.show()
plt.plot(k2, x, label = u'x')
plt.plot(k2h,xh, label = u'hopf(x(k2))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k2sn,xsn, label = u'saddle-node(x(k2))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k2',fontsize=16)
plt.ylabel('x',fontsize=14)
plt.xlabel('k2',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.18,0.5))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 3
# 3
# 0

# %%
k1m = 0.01
k1m = 0.02
k3 = 0.0032
k1 = 1
k3m = 0.0005 #variant
#k3m = 0.001
#k3m = 0.002
#k3m = 0.003
#k3m = 0.004 
x = [round((i+0.001)/1000+0.001,3) for i in range(1000)]
y = [k3/k3m*x[i] for i in range(1000)]
z = [1-x[i]-y[i] for i in range(1000)]
k2 = [(k1*z[i]-k1m*x[i])/(x[i]*(z[i])**2) for i in range(1000)]
a11 = [-k1-k1m-k3-k2[i]+4*k2[i]*x[i]-3*k2[i]*(x[i])**2+2*k2[i]*y[i]-4*k2[i]*y[i]*x[i]-k2[i]*(y[i])**2 for i in range(1000)]
a12 = [-k1+k3m+2*k2[i]*x[i]-2*k2[i]*(x[i])**2-2*k2[i]*x[i]*y[i] for i in range(1000)]
a21 = k3 
a22 = -k3m
sp = [a11[i]+a22 for i in range(1000)]
determ = [a11[i]*a22-a12[i]*a21 for i in range(1000)]
DI = [sp[i]**2-4*determ[i] for i in range(1000)]
index = 1
yh = []
xh = []
k2h = []
ysn = []
xsn = []
k2sn = []
ydi = []
xdi = []
k2di = []
while index < 1000:
    if sp[index]*sp[index-1] <= 0:
        yh.append(y[index])
        xh.append(x[index])
        k2h.append(k2[index])
    if determ[index]*determ[index-1] <= 0:
        ysn.append(y[index])
        xsn.append(x[index])
        k2sn.append(k2[index])
    if DI[index]*DI[index-1] <= 0:
        ydi.append(y[index])
        xdi.append(x[index])
        k2di.append(k2[index])
    index += 1
print(len(xh))
print(len(xsn))
print(len(xdi))
mh = len(xh)
msn = len(xsn)
mdi = len(xdi)
fig = plt.figure()
plt.plot(k2, x, label = u'x')
plt.plot(k2, y, label = u'y', linestyle='--')
plt.plot(k2h,yh, label = u'hopf(y(k2))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k2sn,ysn, label = u'saddle-node(y(k2))', linestyle = 'None', marker='d')
plt.plot(k2h,xh, label = u'hopf(x(k1))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k2sn,xsn, label = u'saddle-node(x(k2))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k2',fontsize=16)
plt.ylabel('x, y',fontsize=14)
plt.xlabel('k2',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0,1))
plt.legend()
plt.grid(True)
plt.show()
fig1 = plt.figure()
plt.plot(k2, y, label = u'y', linestyle='--')
plt.plot(k2h,yh, label = u'hopf(y(k2))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k2sn,ysn, label = u'saddle-node(y(k2))', linestyle = 'None', marker='d')
plt.title('Dependence on Parameter k2',fontsize=16)
plt.ylabel('y',fontsize=14)
plt.xlabel('k2',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.4,0.9))
plt.legend()
plt.grid(True)
plt.show()
plt.plot(k2, x, label = u'x')
plt.plot(k2h,xh, label = u'hopf(x(k2))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k2sn,xsn, label = u'saddle-node(x(k2))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k2',fontsize=16)
plt.ylabel('x',fontsize=14)
plt.xlabel('k2',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.0,0.2))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 3
# 3
# 0

# %%
k1m = 0.01
k1m = 0.02
k3 = 0.0032   
k1 = 1
#k3m = 0.0005 #variant
#k3m = 0.001
#k3m = 0.002
#k3m = 0.003
k3m = 0.004 
x = [round((i+0.001)/1000+0.001,3) for i in range(1000)]
y = [k3/k3m*x[i] for i in range(1000)]
z = [1-x[i]-y[i] for i in range(1000)]
k2 = [(k1*z[i]-k1m*x[i])/(x[i]*(z[i])**2) for i in range(1000)]
a11 = [-k1-k1m-k3-k2[i]+4*k2[i]*x[i]-3*k2[i]*(x[i])**2+2*k2[i]*y[i]-4*k2[i]*y[i]*x[i]-k2[i]*(y[i])**2 for i in range(1000)]
a12 = [-k1+k3m+2*k2[i]*x[i]-2*k2[i]*(x[i])**2-2*k2[i]*x[i]*y[i] for i in range(1000)]
a21 = k3 
a22 = -k3m
sp = [a11[i]+a22 for i in range(1000)]
determ = [a11[i]*a22-a12[i]*a21 for i in range(1000)]
DI = [sp[i]**2-4*determ[i] for i in range(1000)]
index = 1
yh = []
xh = []
k2h = []
ysn = []
xsn = []
k2sn = []
ydi = []
xdi = []
k2di = []
while index < 1000:
    if sp[index]*sp[index-1] <= 0:
        yh.append(y[index])
        xh.append(x[index])
        k2h.append(k2[index])
    if determ[index]*determ[index-1] <= 0:
        ysn.append(y[index])
        xsn.append(x[index])
        k2sn.append(k2[index])
    if DI[index]*DI[index-1] <= 0:
        ydi.append(y[index])
        xdi.append(x[index])
        k2di.append(k2[index])
    index += 1
print(len(xh))
print(len(xsn))
print(len(xdi))
mh = len(xh)
msn = len(xsn)
mdi = len(xdi)
fig = plt.figure()
plt.plot(k2, x, label = u'x')
plt.plot(k2, y, label = u'y', linestyle='--')
plt.plot(k2h,yh, label = u'hopf(y(k2))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k2sn,ysn, label = u'saddle-node(y(k2))', linestyle = 'None', marker='d')
plt.plot(k2h,xh, label = u'hopf(x(k1))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k2sn,xsn, label = u'saddle-node(x(k2))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k2',fontsize=16)
plt.ylabel('x, y',fontsize=14)
plt.xlabel('k2',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0,1))
plt.legend()
plt.grid(True)
plt.show()
fig1 = plt.figure()
plt.plot(k2, y, label = u'y', linestyle='--')
plt.plot(k2h,yh, label = u'hopf(y(k2))', linestyle = 'None', marker='*', markersize = '15')
plt.plot(k2sn,ysn, label = u'saddle-node(y(k2))', linestyle = 'None', marker='d')
plt.title('Dependence on Parameter k2',fontsize=16)
plt.ylabel('y',fontsize=14)
plt.xlabel('k2',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.2,0.5))
plt.legend()
plt.grid(True)
plt.show()
plt.plot(k2, x, label = u'x')
plt.plot(k2h,xh, label = u'hopf(x(k2))', linestyle = 'None', marker='*', markersize = '15', color='b')
plt.plot(k2sn,xsn, label = u'saddle-node(x(k2))', linestyle = 'None', marker='d',color='m')
plt.title('Dependence on Parameter k2',fontsize=16)
plt.ylabel('x',fontsize=14)
plt.xlabel('k2',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0.25,0.6))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 3
# 3
# 0

# %%
# (k1m,k1)
k2 = 2
k3m = 0.002
k3 = 0.0032
x = [round((i+0.001)/1000+0.001,3) for i in range(1000)]
y = [k3/k3m*x[i] for i in range(1000)]
z = [1-x[i]-y[i] for i in range(1000)]
#j = [-z[i]/x[i]-1 for i in range(1000)]

#линия нейтральности
k1 = [(k3+k3m+2*k2*(z[i])**2+2*k2*x[i]*z[i])/(-z[i]/x[i]-1-0.00000000000001) for i in range(1000)]
k1m = [k1[i]*z[i]/x[i]+k2*(z[i])**2 for i in range(1000)]

# линия кратности
K1 = [(2*k2*z[i]*x[i]*(k3+k3m)-2*k2*k3m*(z[i])**2)/(k3m+k3+k3m*z[i]/x[i]) for i in range(1000)] 
K1M = [K1[i]*z[i]/x[i]+k2*(z[i])**2 for i in range(1000)]

fig = plt.figure()
plt.plot(k1m, k1, label = u'hopf line')
plt.plot(K1M, K1, label = u'saddle-node line', linestyle='--')
plt.title('Parametric Portrait',fontsize=16)
plt.ylabel('k1',fontsize=14)
plt.xlabel('k1m',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((-5,20,-10,7.5))
plt.legend()
plt.grid(True)
plt.show()
fig = plt.figure()
plt.plot(k1m, k1, label = u'saddle-node line')
plt.plot(K1M, K1, label = u'hopf line', linestyle='--')
plt.title('Parametric Portrait',fontsize=16)
plt.ylabel('k1',fontsize=14)
plt.xlabel('k1m',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((-2,2,-2,2))
plt.legend()
plt.grid(True)
arrowprops = {
    'arrowstyle': '->',
}
plt.annotate (u'Oscillation region',
                xy=(0.2, 0.0),
                xytext = (0.8, 0.1),
                arrowprops = arrowprops)
plt.show()
fig = plt.figure()
plt.plot(k1m, k1, label = u'saddle-node line')
plt.plot(K1M, K1, label = u'hopf line', linestyle='--')
plt.title('Parametric Portrait',fontsize=16)
plt.ylabel('k1',fontsize=14)
plt.xlabel('k1m',fontsize=14)
x1,x2,y1,y2 = plt.axis()
plt.axis((-2.5,2,-1,4))
plt.legend()
plt.grid(True)
arrowprops = {
    'arrowstyle': '->',
}
plt.annotate (u'C',
                xy=(-0.8, 1.7),
                xytext = (-0.8, 2.5),
                arrowprops = arrowprops,fontsize=18)
plt.annotate (u'I',
                xy=(0.5, 2),fontsize=24)
plt.annotate (u'II',
                xy=(-2, 2.9),
                xytext = (-2.2, 3.5),
                arrowprops = arrowprops,fontsize=24)
plt.annotate (u'III',
                xy=(-1.5, 1),fontsize=24)
plt.show()
