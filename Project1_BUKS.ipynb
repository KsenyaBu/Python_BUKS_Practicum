# %%
import sys        
import traceback
import random
import math
import time
import pdb
from pdb import set_trace as bp


from OpenGL.GL import *
from OpenGL.GLU import *
from OpenGL.GLUT import *
from PyQt5.QtWidgets import QApplication, QWidget
from PyQt5 import QtCore, QtGui, QtWidgets,uic
from PyQt5.QtOpenGL import *

# %%
class Position:
    _x = 0
    _y = 0
    _z = 0
    def __init__ (self,x,y,z):
        self._x = x
        self._y = y
        self._z = z
    def print_info(self):
        print ('_x:',self._x, '_y:',self._y, '_z:',self._z)
        
class Speed:
    _u = 0
    _v = 0
    _w = 0
    def __init__ (self,u,v,w):
        self._u = u
        self._v = v
        self._w = w
    def print_info(self):
        print ('_u:',self._u, '_v:',self._v, '_w:',self._w)

class Item(Position, Speed):
    _m = 0
    _color = ''
    _lifetime = 0    
    def __init__(self,x,y,z,u,v,w,m,color,lifetime):
        Position.__init__(self, x, y, z)
        Speed.__init__(self, u, v, w)
        self._m = m
        self._color = color
        self._lifetime = lifetime
    def print_info(self):
        print ('_x:',self._x, '_y:', self._y, '_z:', self._z,'_u:', self._u, '_v:', self._v, '_w:', self._w, '_m:', self._m, '_color:', 

self._color, '_lifetime', self._lifetime)
        
class Emitter(Position,Speed):
    def __init__(self,x,y,z,u,v,w):
        Position.__init__(self, x, y, z)
        Speed.__init__(self, u, v, w)
    def print_info(self):
        print ('_x:',self._x, '_y:', self._y, '_z:', self._z,'_u:', self._u, '_v:', self._v, '_w:', self._w)

def items_generate():
    print(ui.lineEdit.text())
    color_list = ["green", "red", "blue", "yellow", "orange"]
#    print(len(ui.lineEdit.text()))
    if len(ui.lineEdit.text()) == 0:
        ui.msg = QtWidgets.QMessageBox()
        ui.msg.setIcon(QtWidgets.QMessageBox.Warning)
        ui.msg.setText("Fill in the number of items to generate")
        ui.msg.show()
    else:
        N = int(ui.lineEdit.text())
        for i in range(N):
            x_item = random.uniform(-10, 10)
            y_item = random.uniform(-10, 10)
            z_item = random.uniform(-10, 10)
            u_item = random.uniform(-10, 10)
            v_item = random.uniform(-10, 10)
            w_item = random.uniform(-10, 10)
            m_item = random.uniform(1000, 10000)
            color_item = random.choice(color_list)
            time_item = random.uniform(200, 20000)
            s.append(Item(x_item,y_item,z_item,u_item,v_item,w_item,m_item,color_item,time_item))
#        for i in range(len(s)):
#            print(s[i].print_info())    
    return

def item_generate():
    if (len(ui.lineEdit_8.text()) == 0) or (len(ui.lineEdit_9.text()) == 0) or (len(ui.lineEdit_10.text()) == 0) or (len(ui.lineEdit_11.text()) == 0) or (len(ui.lineEdit_12.text()) == 0) or (len(ui.lineEdit_13.text()) == 0) or (len(ui.lineEdit_14.text()) == 0) or (len(ui.lineEdit_16.text()) == 0):
        ui.msg1 = QtWidgets.QMessageBox()
        ui.msg1.setIcon(QtWidgets.QMessageBox.Warning)
        ui.msg1.setText("One of the fields with item's parameters is empty")
        ui.msg1.show()
    else:
        color_str = str(ui.comboBox_2.currentText())
        x1_item = float(ui.lineEdit_8.text().replace(',','.'))
        y1_item = float(ui.lineEdit_9.text().replace(',','.'))
        z1_item = float(ui.lineEdit_10.text().replace(',','.'))
        u1_item = float(ui.lineEdit_11.text().replace(',','.'))
        v1_item = float(ui.lineEdit_12.text().replace(',','.'))
        w1_item = float(ui.lineEdit_13.text().replace(',','.')) 
        m1_item = float(ui.lineEdit_14.text().replace(',','.')) 
        time_item1 = float(ui.lineEdit_16.text().replace(',','.')) 
        s.append(Item(x1_item,y1_item,z1_item,u1_item,v1_item,w1_item,m1_item,color_str,time_item1))
#        for i in range(len(s)):
#            print(s[i].print_info())

# %%
#%%debug
class Load_window(QtWidgets.QMainWindow):
    
    def __init__(self):
        super(Load_window, self).__init__()
        uic.loadUi('BUKS1.ui', self)
        self.openGLWidget.initializeGL()
        self.openGLWidget.initializeGL = self.initializeGL
        self.openGLWidget.paintGL = self.paintGL
        self._timer = QtCore.QTimer()
        #self._timer.timeout.connect(self.repainting)
        self._timer.start()
        self.show()
        
    def initializeGL(self):
        print('InitializeGL')
        glClear(GL_COLOR_BUFFER_BIT)
        glEnable(GL_DEPTH_TEST) # включаем буфер глубин
        glEnable(GL_ALPHA_TEST) # включение четвёртого компонента цвета
        ambient = [1.0, 1.0, 1.0, 1]
        glLightModelfv(GL_LIGHT_MODEL_AMBIENT, ambient)
        glEnable(GL_LIGHTING)
        lightZeroPosition = [-15, -20 , -30, 0.8]
        lightZeroColor = [0.8, 1.0, 0.8, 1.0]
        glLightfv(GL_LIGHT0, GL_POSITION, lightZeroPosition)
        glLightf(GL_LIGHT0, GL_LINEAR_ATTENUATION, 0.02)
        glEnable(GL_LIGHT0)
        glMatrixMode(GL_PROJECTION) # задание текущей матрицы GL_PROJECTION (проекции), т.е. той матрицы, на которую будут воздействовать 
        #последующие вызовы
        # команд glLoadIdentity, glRotate, glTranslate, glMultMatrix
        glLoadIdentity() # замена текущей матрицы (проекции) на единичную
        #gluPerspective(45, 1, 1, 1) #умножение на перспективную матрицу
        glMatrixMode(GL_MODELVIEW) #задание текущей матрицы преобразований
        glLoadIdentity() # замена текущей матрицы (преобразований) на единичную
        
    def repainting(self):
        global color_init
        global x_init
        global y_init
        global z_init
        global m_init
    #    print(x_init)
        glLoadIdentity() #сброс просмотра
        glClear(GL_COLOR_BUFFER_BIT | GL_DEPTH_BUFFER_BIT)
        quadObj = gluNewQuadric()   #cоздаем новый объект для создания сфер и цилиндров                      
        for h in range(len(color_init)):
            glTranslated(x_init[h]/100,y_init[h]/100,z_init[h]/100)
            color = color_init[h]
            glMaterialfv(GL_FRONT, GL_DIFFUSE, color)
            gluQuadricDrawStyle(quadObj, GLU_FILL)
            gluSphere(quadObj, 0.00001*(m_init[h]), 40, 40)
            glTranslated(-x_init[h]/100,-y_init[h]/100,-z_init[h]/100)
        gluDeleteQuadric(quadObj)
        self.openGLWidget.update()
        print ("repainting")
        
        
    def paintGL(self):
        global activate
        #print('paintGL')
        glLoadIdentity() #сброс просмотра
        glClear(GL_COLOR_BUFFER_BIT | GL_DEPTH_BUFFER_BIT)
        glClearColor(0.2, 0.0, 0.2, 1.0)
        if (self._timer.isActive() and activate == 1):
#            bp()
            self.repainting()
        self.openGLWidget.update()

    def calculate_update(self):
        global activate
        global color_init
        global x_init
        global y_init
        global z_init
        global m_init
        num_of_iterations = int(ui.lineEdit_17.text())
        time1 = float(ui.lineEdit_18.text().replace(',','.'))
        delta_t = time1/num_of_iterations
        current_time = 0
        count = 1
        list_of_timelife = []
        binary_time = []
        for k in range(len(s)):
            list_of_timelife.append(s[k]._lifetime)
            binary_time.append(1)
        result_list = []
        for l in range(len(s)):                               #initialization of 2-D list
            x = []
            result_list.append(x)
            result_list[l].append(s[l]) 
        while count <= num_of_iterations:
            color_init = []
            x_init = []
            y_init = []
            z_init = []
            m_init = []
            for k in range(len(binary_time)):                 #dead or not dead
                if (list_of_timelife[k] < current_time):
                    binary_time[k] = 0        
            for l in range(len(s)):
                if count <= len(result_list[l]):
                    if (result_list[l][count-1]._color == 'red'):
                        color_init.append([1.0, 0.0, 0.0, 1.0])
                    else:
                        if (result_list[l][count-1]._color == 'blue'):
                            color_init.append([0.0, 0.0, 1.0, 1.0])
                        else:
                            if (result_list[l][count-1]._color == 'green'):
                                color_init.append([0.0, 0.0, 1.0, 1.0])
                            else:
                                if (result_list[l][count-1]._color == 'orange'):
                                    color_init.append([1.0, 0.6, 0.0, 1.0])
                                else:
                                    color_init.append([1.0, 1.0, 0.0, 1.0])
                    x_init.append(result_list[l][count-1]._x)
                    y_init.append(result_list[l][count-1]._y)
                    z_init.append(result_list[l][count-1]._z)
                    m_init.append(result_list[l][count-1]._m)
            print ("calculate")
            print (count)
           # if (self._timer.isActive()):
           #     print ("repaint")
            x_prev = []
            y_prev = []
            z_prev = []
            u_prev = []
            v_prev = []
            w_prev = []
            m_prev = []
            color_prev = []
            lifetime_prev = []
            for m in range(len(result_list)):                 #remember previous coordinates for each item//
                index = len(result_list[m]) - 1               #fill in lists
                x_prev.append(result_list[m][index]._x)
                y_prev.append(result_list[m][index]._y)
                z_prev.append(result_list[m][index]._z)
                u_prev.append(result_list[m][index]._u)
                v_prev.append(result_list[m][index]._v)
                w_prev.append(result_list[m][index]._w)
                m_prev.append(result_list[m][index]._m)
                color_prev.append(result_list[m][index]._color)
                lifetime_prev.append(result_list[m][index]._lifetime)
            a1_prev = []
            a2_prev = []
            a3_prev = [] 
            for z in range(len(result_list)):                 #calculate previous acceleration for each item
                a1_prev.append(0)
                a2_prev.append(0)
                a3_prev.append(0)
                for n in range(len(result_list)):             #sum in acceleration's calculation
                    if (n != z):
                        const_absolute = math.sqrt((x_prev[n] - x_prev[z])**2 + (y_prev[n] - y_prev[z])**2 + (z_prev[n] - z_prev[z])**2)
                        const = 6.67408*(10**(-11))*m_prev[n]
                        #bp()
                        print(const_absolute)
                        print(x_prev[n])
                        print(x_prev[z])
                        a1_prev[z] += const*(x_prev[n] - x_prev[z])/(const_absolute**3) 
                        a2_prev[z] += const*(y_prev[n] - y_prev[z])/(const_absolute**3)
                        a3_prev[z] += const*(z_prev[n] - z_prev[z])/(const_absolute**3)
            x_n = []
            y_n = []
            z_n = []
            for i in range(len(result_list)):                 #next coordinates
                x_n.append(x_prev[i] + u_prev[i]*delta_t + 1/2*a1_prev[i]*(delta_t**2))
                y_n.append(y_prev[i] + v_prev[i]*delta_t + 1/2*a2_prev[i]*(delta_t**2))
                z_n.append(x_prev[i] + w_prev[i]*delta_t + 1/2*a3_prev[i]*(delta_t**2))
            a1_n = []
            a2_n = []
            a3_n = []
            for z in range(len(result_list)):             #calculate next acceleration for each item
                a1_n.append(0)
                a2_n.append(0)
                a3_n.append(0)
                for n in range(len(result_list)):             #sum in acceleration's calculation
                    if (n != z):
                        const_absolute = math.sqrt((x_n[n] - x_n[z])**2 + (y_n[n] - y_n[z])**2 + (z_n[n] - z_n[z])**2)
                        const = 6.67408*(10**(-11))*m_prev[n]
                        a1_n[z] += const*(x_n[n] - x_n[z])/(const_absolute**3) 
                        a2_n[z] += const*(y_n[n] - y_n[z])/(const_absolute**3)
                        a3_n[z] += const*(z_n[n] - z_n[z])/(const_absolute**3)
            u_n = []
            v_n = []
            w_n = []
            for i in range(len(result_list)):
                u_n.append(u_prev[i] + 1/2*(a1_prev[i]+a1_n[i])*delta_t)
                v_n.append(v_prev[i] + 1/2*(a2_prev[i]+a2_n[i])*delta_t)
                w_n.append(w_prev[i] + 1/2*(a3_prev[i]+a3_n[i])*delta_t)
                if (binary_time[i] != 0):
                    result_list[i].append(Item(x_n[i],y_n[i],z_n[i],u_n[i],v_n[i],w_n[i],m_prev[i],color_prev[i],lifetime_prev[i]))
            count += 1
            #    print("Active")
            ''' if count > num_of_iterations:
                self._timer.stop()
                print('stop')   '''
            current_time += delta_t
            print(x_init)
            self.openGLWidget.repaint()
#            bp()
       #     self.openGLWidget.repaint()
#            bp()
        activate = 0

# %%
def calculation():
    if len(s) == 0:
        ui.msg2 = QtWidgets.QMessageBox()
        ui.msg2.setIcon(QtWidgets.QMessageBox.Warning)
        ui.msg2.setText("The list of items is empty")
        ui.msg2.show()
    else:
        if (len(ui.lineEdit_17.text()) == 0) or (int(ui.lineEdit_17.text()) == 0):
            ui.msg3 = QtWidgets.QMessageBox()
            ui.msg3.setIcon(QtWidgets.QMessageBox.Warning)
            ui.msg3.setText("Fill in the number of iterations")
            ui.msg3.show()
        else:
            if (len(ui.lineEdit_18.text()) == 0):
                ui.msg4 = QtWidgets.QMessageBox()
                ui.msg4.setIcon(QtWidgets.QMessageBox.Warning)
                ui.msg4.setText("Fill in the arbitrary time")
                ui.msg4.show()
            else:
                num_of_iterations = int(ui.lineEdit_17.text())
                time1 = float(ui.lineEdit_18.text().replace(',','.'))
                delta_t = time1/num_of_iterations
                if str(ui.comboBox.currentText()) == "Verlet method":
                    print('Verlet')
                    global activate
                    activate = 1
                    ui.calculate_update()

# %%
if __name__ == '__main__':
    s = []
    color_init = []
    x_init = []
    y_init = []
    z_init = []
    m_init = []
    h = 0
    activate = 0
    app = QApplication(sys.argv)
    app.aboutToQuit.connect(app.deleteLater)   # help not to kill kernel 
    ui = Load_window()
    int_validator = QtGui.QIntValidator()
    dbl_validator = QtGui.QDoubleValidator()
    ui.lineEdit.setValidator(int_validator)
    ui.lineEdit_8.setValidator(dbl_validator)
    ui.lineEdit_9.setValidator(dbl_validator)
    ui.lineEdit_10.setValidator(dbl_validator)
    ui.lineEdit_11.setValidator(dbl_validator)
    ui.lineEdit_12.setValidator(dbl_validator)
    ui.lineEdit_13.setValidator(dbl_validator)
    ui.lineEdit_14.setValidator(dbl_validator)
    ui.lineEdit_16.setValidator(dbl_validator)
    ui.lineEdit_17.setValidator(int_validator)
    ui.lineEdit_18.setValidator(dbl_validator)
    ui.pushButton_2.clicked.connect(items_generate)
    ui.pushButton.clicked.connect(item_generate)
    ui.pushButton_3.clicked.connect(calculation)
    sys.exit(app.exec_())
# Out:
# InitializeGL
# Verlet
# calculate
# 1
# 1.1313708498984762
# 0.8
# 0.0
# 1.1313708498984762
# 0.0
# 0.8
# [0.0, 0.8]
# repainting
# calculate
# 2
# 1.442220478230157
# 1.1999999907826424
# 1.3826036795453643e-08
# 1.442220478230157
# 1.3826036795453643e-08
# 1.1999999907826424
# [1.3826036795453643e-08, 1.1999999907826424]
# repainting
# calculate
# 3
# 1.999999895431593
# 1.599999968216317
# 4.767552488029801e-08
# 1.999999895431593
# 4.767552488029801e-08
# 1.599999968216317
# [4.767552488029801e-08, 1.599999968216317]
# repainting
# calculate
# 4
# 2.5612494900949896
# 1.9999999389759109
# 9.153613403824048e-08
# 2.5612494900949896
# 9.153613403824048e-08
# 1.9999999389759109
# [9.153613403824048e-08, 1.9999999389759109]
# repainting
# calculate
# 5
# 3.1240995496171573
# 2.399999905763263
# 1.4135510648524604e-07
# 3.1240995496171573
# 1.4135510648524604e-07
# 2.399999905763263
# [1.4135510648524604e-07, 2.399999905763263]
# repainting
# calculate
# 6
# 3.687817336342552
# 2.7999998699239903
# 1.9511401593555076e-07
# 3.687817336342552
# 1.9511401593555076e-07
# 2.7999998699239903
# [1.9511401593555076e-07, 2.7999998699239903]
# repainting
# calculate
# 7
# 4.252057745760701
# 3.199999832221725
# 2.5166741466365616e-07
# 4.252057745760701
# 2.5166741466365616e-07
# 3.199999832221725
# [2.5166741466365616e-07, 3.199999832221725]
# repainting
# calculate
# 8
# 4.816637114323385
# 3.5999997931304217
# 3.1030436916938603e-07
# 4.816637114323385
# 3.1030436916938603e-07
# 3.5999997931304217
# [3.1030436916938603e-07, 3.5999997931304217]
# calculate
# 9
# 5.381448759860873
# 3.9999997529640603
# 3.7055391131432174e-07
# 5.381448759860873
# 3.7055391131432174e-07
# 3.9999997529640603
# [3.7055391131432174e-07, 3.9999997529640603]
# calculate
# 10
# 5.946426495083999
# 4.399999711941206
# 4.3208819263530976e-07
# 5.946426495083999
# 4.3208819263530976e-07
# 4.399999711941206
# [4.3208819263530976e-07, 4.399999711941206]
# calculate
# 11
# 6.511527087205879
# 4.799999670220045
# 4.946699331484242e-07
# 6.511527087205879
# 4.946699331484242e-07
# 4.799999670220045
# [4.946699331484242e-07, 4.799999670220045]
# calculate
# 12
# 7.076721104474008
# 5.199999627918716
# 5.58121926161857e-07
# 7.076721104474008
# 5.58121926161857e-07
# 5.199999627918716
# [5.58121926161857e-07, 5.199999627918716]
# calculate
# 13
# 7.641987817882515
# 5.599999585127757
# 6.22308364882248e-07
# 7.641987817882515
# 6.22308364882248e-07
# 5.599999585127757
# [6.22308364882248e-07, 5.599999585127757]
# repainting
# calculate
# 14
# 8.207312206815425
# 5.999999541918072
# 6.871228931919038e-07
# 8.207312206815425
# 6.871228931919038e-07
# 5.999999541918072
# [6.871228931919038e-07, 5.999999541918072]
# calculate
# 15
# 8.772683121111411
# 6.399999498346219
# 7.524806730538801e-07
# 8.772683121111411
# 7.524806730538801e-07
# 6.399999498346219
# [7.524806730538801e-07, 6.399999498346219]
# calculate
# 16
# 9.338092110127665
# 6.7999994544580336
# 8.183129518410353e-07
# 9.338092110127665
# 8.183129518410353e-07
# 6.7999994544580336
# [8.183129518410353e-07, 6.7999994544580336]
# calculate
# 17
# 9.903532652562703
# 7.199999410291174
# 8.845632409797357e-07
# 9.903532652562703
# 8.845632409797357e-07
# 7.199999410291174
# [8.845632409797357e-07, 7.199999410291174]
# calculate
# 18
# 10.46899963567932
# 7.5999993658769585
# 9.511845649361947e-07
# 10.46899963567932
# 9.511845649361947e-07
# 7.5999993658769585
# [9.511845649361947e-07, 7.5999993658769585]
# calculate
# 19
# 11.034488994545796
# 7.999999321241709
# 1.018137440104096e-06
# 11.034488994545796
# 1.018137440104096e-06
# 7.999999321241709
# [1.018137440104096e-06, 7.999999321241709]
# calculate
# 20
# 11.599997456734817
# 8.39999927640776
# 1.085388363050247e-06
# 11.599997456734817
# 1.085388363050247e-06
# 8.39999927640776
# [1.085388363050247e-06, 8.39999927640776]
# calculate
# 21
# 12.165522358190055
# 8.799999231394228
# 1.1529086615512132e-06
# 12.165522358190055
# 1.1529086615512132e-06
# 8.799999231394228
# [1.1529086615512132e-06, 8.799999231394228]
# calculate
# 22
# 12.731061508145615
# 9.199999186217596
# 1.2206736087818997e-06
# 12.731061508145615
# 1.2206736087818997e-06
# 9.199999186217596
# [1.2206736087818997e-06, 9.199999186217596]
# calculate
# 23
# 13.296613088502621
# 9.59999914089218
# 1.2886617315317237e-06
# 13.296613088502621
# 1.2886617315317237e-06
# 9.59999914089218
# [1.2886617315317237e-06, 9.59999914089218]
# repainting
# calculate
# 24
# 13.862175577827657
# 9.999999095430493
# 1.356854263610499e-06
# 13.862175577827657
# 1.356854263610499e-06
# 9.999999095430493
# [1.356854263610499e-06, 9.999999095430493]
# calculate
# 25
# 14.427747693220226
# 10.39999904984353
# 1.4252347093648346e-06
# 14.427747693220226
# 1.4252347093648346e-06
# 10.39999904984353
# [1.4252347093648346e-06, 10.39999904984353]
# calculate
# 26
# 14.993328345333047
# 10.799999004141007
# 1.4937884917276107e-06
# 14.993328345333047
# 1.4937884917276107e-06
# 10.799999004141007
# [1.4937884917276107e-06, 10.799999004141007]
# calculate
# 27
# 15.558916603199682
# 11.199998958331557
# 1.5625026658940322e-06
# 15.558916603199682
# 1.5625026658940322e-06
# 11.199998958331557
# [1.5625026658940322e-06, 11.199998958331557]
# calculate
# 28
# 16.124511666462425
# 11.599998912422878
# 1.6313656844722937e-06
# 16.124511666462425
# 1.6313656844722937e-06
# 11.599998912422878
# [1.6313656844722937e-06, 11.599998912422878]
# calculate
# 29
# 16.690112843245593
# 11.999998866421864
# 1.7003672033927575e-06
# 16.690112843245593
# 1.7003672033927575e-06
# 11.999998866421864
# [1.7003672033927575e-06, 11.999998866421864]
# calculate
# 30
# 17.25571953237934
# 12.39999882033472
# 1.769497920374271e-06
# 17.25571953237934
# 1.769497920374271e-06
# 12.39999882033472
# [1.769497920374271e-06, 12.39999882033472]
# calculate
# 31
# 17.821331209007774
# 12.799998774167038
# 1.8387494396086077e-06
# 17.821331209007774
# 1.8387494396086077e-06
# 12.799998774167038
# [1.8387494396086077e-06, 12.799998774167038]
# calculate
# 32
# 18.386947412852795
# 13.199998727923893
# 1.9081141577183437e-06
# 18.386947412852795
# 1.9081141577183437e-06
# 13.199998727923893
# [1.9081141577183437e-06, 13.199998727923893]
# calculate
# 33
# 18.952567738579084
# 13.599998681609886
# 1.9775851670980686e-06
# 18.952567738579084
# 1.9775851670980686e-06
# 13.599998681609886
# [1.9775851670980686e-06, 13.599998681609886]
# calculate
# 34
# 19.51819182783404
# 13.999998635229217
# 2.0471561735540165e-06
# 19.51819182783404
# 2.0471561735540165e-06
# 13.999998635229217
# [2.0471561735540165e-06, 13.999998635229217]
# calculate
# 35
# 20.083819362632585
# 14.399998588785715
# 2.116821425777424e-06
# 20.083819362632585
# 2.116821425777424e-06
# 14.399998588785715
# [2.116821425777424e-06, 14.399998588785715]
# calculate
# 36
# 20.649450059828993
# 14.799998542282896
# 2.186575654668654e-06
# 20.649450059828993
# 2.186575654668654e-06
# 14.799998542282896
# [2.186575654668654e-06, 14.799998542282896]
# repainting
# calculate
# 37
# 21.215083666472974
# 15.199998495723985
# 2.2564140209061725e-06
# 21.215083666472974
# 2.2564140209061725e-06
# 15.199998495723985
# [2.2564140209061725e-06, 15.199998495723985]
# calculate
# 38
# 21.780719955889207
# 15.599998449111954
# 2.3263320694517826e-06
# 21.780719955889207
# 2.3263320694517826e-06
# 15.599998449111954
# [2.3263320694517826e-06, 15.599998449111954]
# calculate
# 39
# 22.34635872435223
# 15.99999840244954
# 2.3963256899195345e-06
# 22.34635872435223
# 2.3963256899195345e-06
# 15.99999840244954
# [2.3963256899195345e-06, 15.99999840244954]
# calculate
# 40
# 22.911999788253812
# 16.399998355739278
# 2.466391081924347e-06
# 22.911999788253812
# 2.466391081924347e-06
# 16.399998355739278
# [2.466391081924347e-06, 16.399998355739278]
# calculate
# 41
# 23.47764298167972
# 16.799998308983515
# 2.5365247246780097e-06
# 23.47764298167972
# 2.5365247246780097e-06
# 16.799998308983515
# [2.5365247246780097e-06, 16.799998308983515]
# calculate
# 42
# 24.04328815432852
# 17.19999826218443
# 2.6067233502228584e-06
# 24.04328815432852
# 2.6067233502228584e-06
# 17.19999826218443
# [2.6067233502228584e-06, 17.19999826218443]
# repainting
# calculate
# 43
# 24.608935169717384
# 17.599998215344048
# 2.676983919793129e-06
# 24.608935169717384
# 2.676983919793129e-06
# 17.599998215344048
# [2.676983919793129e-06, 17.599998215344048]
# calculate
# 44
# 25.17458390362972
# 17.99999816846426
# 2.7473036028754946e-06
# 25.17458390362972
# 2.7473036028754946e-06
# 17.99999816846426
# [2.7473036028754946e-06, 17.99999816846426]
# calculate
# 45
# 25.740234242767492
# 18.39999812154682
# 2.8176797586072402e-06
# 25.740234242767492
# 2.8176797586072402e-06
# 18.39999812154682
# [2.8176797586072402e-06, 18.39999812154682]
# calculate
# 46
# 26.30588608357738
# 18.79999807459338
# 2.8881099192057943e-06
# 26.30588608357738
# 2.8881099192057943e-06
# 18.79999807459338
# [2.8881099192057943e-06, 18.79999807459338]
# calculate
# 47
# 26.8715393312252
# 19.199998027605478
# 2.9585917751691375e-06
# 26.8715393312252
# 2.9585917751691375e-06
# 19.199998027605478
# [2.9585917751691375e-06, 19.199998027605478]
# calculate
# 48
# 27.437193898697178
# 19.599997980584554
# 3.0291231620247697e-06
# 27.437193898697178
# 3.0291231620247697e-06
# 19.599997980584554
# [3.0291231620247697e-06, 19.599997980584554]
# calculate
# 49
# 28.002849706010085
# 19.99999793353196
# 3.0997020484367933e-06
# 28.002849706010085
# 3.0997020484367933e-06
# 19.99999793353196
# [3.0997020484367933e-06, 19.99999793353196]
# calculate
# 50
# 28.568506679515313
# 20.399997886448975
# 3.17032652550746e-06
# 28.568506679515313
# 3.17032652550746e-06
# 20.399997886448975
# [3.17032652550746e-06, 20.399997886448975]
# calculate
# 51
# 29.13416475128391
# 20.799997839336793
# 3.2409947971320622e-06
# 29.13416475128391
# 3.2409947971320622e-06
# 20.799997839336793
# [3.2409947971320622e-06, 20.799997839336793]
# calculate
# 52
# 29.69982385856192
# 21.199997792196545
# 3.311705171285142e-06
# 29.69982385856192
# 3.311705171285142e-06
# 21.199997792196545
# [3.311705171285142e-06, 21.199997792196545]
# calculate
# 53
# 30.265483943286814
# 21.599997745029288
# 3.3824560521321495e-06
# 30.265483943286814
# 3.3824560521321495e-06
# 21.599997745029288
# [3.3824560521321495e-06, 21.599997745029288]
# calculate
# 54
# 30.831144951657123
# 21.999997697836037
# 3.4532459328744777e-06
# 30.831144951657123
# 3.4532459328744777e-06
# 21.999997697836037
# [3.4532459328744777e-06, 21.999997697836037]
# calculate
# 55
# 31.39680683374865
# 22.39999765061773
# 3.524073389247558e-06
# 31.39680683374865
# 3.524073389247558e-06
# 22.39999765061773
# [3.524073389247558e-06, 22.39999765061773]
# calculate
# 56
# 31.9624695431713
# 22.799997603375274
# 3.5949370736017667e-06
# 31.9624695431713
# 3.5949370736017667e-06
# 22.799997603375274
# [3.5949370736017667e-06, 22.799997603375274]
# calculate
# 57
# 32.52813303676189
# 23.19999755610952
# 3.6658357095045716e-06
# 32.52813303676189
# 3.6658357095045716e-06
# 23.19999755610952
# [3.6658357095045716e-06, 23.19999755610952]
# calculate
# 58
# 33.093797274308336
# 23.599997508821268
# 3.736768086809789e-06
# 33.093797274308336
# 3.736768086809789e-06
# 23.599997508821268
# [3.736768086809789e-06, 23.599997508821268]
# calculate
# 59
# 33.659462218301655
# 23.99999746151129
# 3.807733057146278e-06
# 33.659462218301655
# 3.807733057146278e-06
# 23.99999746151129
# [3.807733057146278e-06, 23.99999746151129]
# calculate
# 60
# 34.22512783371266
# 24.399997414180305
# 3.87872952978397e-06
# 34.22512783371266
# 3.87872952978397e-06
# 24.399997414180305
# [3.87872952978397e-06, 24.399997414180305]
# repainting
# calculate
# 61
# 34.79079408779029
# 24.799997366829015
# 3.9497564678399945e-06
# 34.79079408779029
# 3.9497564678399945e-06
# 24.799997366829015
# [3.9497564678399945e-06, 24.799997366829015]
# repainting
# calculate
# 62
# 35.35646094987947
# 25.19999731945807
# 4.020812884791859e-06
# 35.35646094987947
# 4.020812884791859e-06
# 25.19999731945807
# [4.020812884791859e-06, 25.19999731945807]
# repainting
# calculate
# 63
# 35.92212839125597
# 25.599997272068098
# 4.091897841268355e-06
# 35.92212839125597
# 4.091897841268355e-06
# 25.599997272068098
# [4.091897841268355e-06, 25.599997272068098]
# repainting
# calculate
# 64
# 36.487796384976846
# 25.999997224659698
# 4.163010442092047e-06
# 36.487796384976846
# 4.163010442092047e-06
# 25.999997224659698
# [4.163010442092047e-06, 25.999997224659698]
# repainting
# calculate
# 65
# 37.05346490574442
# 26.399997177233434
# 4.2341498335500535e-06
# 37.05346490574442
# 4.2341498335500535e-06
# 26.399997177233434
# [4.2341498335500535e-06, 26.399997177233434]
# repainting
# calculate
# 66
# 37.6191339297826
# 26.799997129789855
# 4.3053152008722925e-06
# 37.6191339297826
# 4.3053152008722925e-06
# 26.799997129789855
# [4.3053152008722925e-06, 26.799997129789855]
# calculate
# 67
# 38.184803434724174
# 27.199997082329478
# 4.3765057658985546e-06
# 38.184803434724174
# 4.3765057658985546e-06
# 27.199997082329478
# [4.3765057658985546e-06, 27.199997082329478]
# calculate
# 68
# 38.75047339950798
# 27.5999970348528
# 4.44772078491768e-06
# 38.75047339950798
# 4.44772078491768e-06
# 27.5999970348528
# [4.44772078491768e-06, 27.5999970348528]
# calculate
# 69
# 39.31614380428495
# 27.99999698736029
# 4.518959546663836e-06
# 39.31614380428495
# 4.518959546663836e-06
# 27.99999698736029
# [4.518959546663836e-06, 27.99999698736029]
# repainting
# calculate
# 70
# 39.88181463033214
# 28.399996939852407
# 4.590221370456378e-06
# 39.88181463033214
# 4.590221370456378e-06
# 28.399996939852407
# [4.590221370456378e-06, 28.399996939852407]
# calculate
# 71
# 40.44748585997405
# 28.799996892329585
# 4.6615056044711305e-06
# 40.44748585997405
# 4.6615056044711305e-06
# 28.799996892329585
# [4.6615056044711305e-06, 28.799996892329585]
# calculate
# 72
# 41.01315747651028
# 29.19999684479224
# 4.732811624132089e-06
# 41.01315747651028
# 4.732811624132089e-06
# 29.19999684479224
# [4.732811624132089e-06, 29.19999684479224]
# calculate
# 73
# 41.57882946414931
# 29.599996797240767
# 4.804138830613634e-06
# 41.57882946414931
# 4.804138830613634e-06
# 29.599996797240767
# [4.804138830613634e-06, 29.599996797240767]
# calculate
# 74
# 42.14450180794741
# 29.999996749675553
# 4.875486649444247e-06
# 42.14450180794741
# 4.875486649444247e-06
# 29.999996749675553
# [4.875486649444247e-06, 29.999996749675553]
# repainting
# calculate
# 75
# 42.710174493752575
# 30.399996702096967
# 4.9468545292036095e-06
# 42.710174493752575
# 4.9468545292036095e-06
# 30.399996702096967
# [4.9468545292036095e-06, 30.399996702096967]
# calculate
# 76
# 43.27584750815275
# 30.799996654505357
# 5.018241940305661e-06
# 43.27584750815275
# 5.018241940305661e-06
# 30.799996654505357
# [5.018241940305661e-06, 30.799996654505357]
# calculate
# 77
# 43.84152083842808
# 31.199996606901067
# 5.089648373860928e-06
# 43.84152083842808
# 5.089648373860928e-06
# 31.199996606901067
# [5.089648373860928e-06, 31.199996606901067]
# calculate
# 78
# 44.40719447250684
# 31.59999655928442
# 5.1610733406119905e-06
# 44.40719447250684
# 5.1610733406119905e-06
# 31.59999655928442
# [5.1610733406119905e-06, 31.59999655928442]
# calculate
# 79
# 44.97286839892468
# 31.999996511655734
# 5.232516369936517e-06
# 44.97286839892468
# 5.232516369936517e-06
# 31.999996511655734
# [5.232516369936517e-06, 31.999996511655734]
# calculate
# 80
# 45.53854260678688
# 32.39999646401531
# 5.30397700891279e-06
# 45.53854260678688
# 5.30397700891279e-06
# 32.39999646401531
# [5.30397700891279e-06, 32.39999646401531]
# calculate
# 81
# 46.104217085733445
# 32.799996416363435
# 5.3754548214430846e-06
# 46.104217085733445
# 5.3754548214430846e-06
# 32.799996416363435
# [5.3754548214430846e-06, 32.799996416363435]
# calculate
# 82
# 46.66989182590661
# 33.19999636870039
# 5.44694938743064e-06
# 46.66989182590661
# 5.44694938743064e-06
# 33.19999636870039
# [5.44694938743064e-06, 33.19999636870039]
# calculate
# 83
# 47.23556681792089
# 33.599996321026445
# 5.5184603020063595e-06
# 47.23556681792089
# 5.5184603020063595e-06
# 33.599996321026445
# [5.5184603020063595e-06, 33.599996321026445]
# calculate
# 84
# 47.80124205283506
# 33.999996273341864
# 5.589987174801657e-06
# 47.80124205283506
# 5.589987174801657e-06
# 33.999996273341864
# [5.589987174801657e-06, 33.999996273341864]
# repainting
# calculate
# 85
# 48.36691752212615
# 34.399996225646895
# 5.661529629264199e-06
# 48.36691752212615
# 5.661529629264199e-06
# 34.399996225646895
# [5.661529629264199e-06, 34.399996225646895]
# calculate
# 86
# 48.932593217665364
# 34.79999617794178
# 5.733087302013537e-06
# 48.932593217665364
# 5.733087302013537e-06
# 34.79999617794178
# [5.733087302013537e-06, 34.79999617794178]
# calculate
# 87
# 49.49826913169549
# 35.19999613022676
# 5.8046598422338695e-06
# 49.49826913169549
# 5.8046598422338695e-06
# 35.19999613022676
# [5.8046598422338695e-06, 35.19999613022676]
# calculate
# 88
# 50.06394525680987
# 35.599996082502045
# 5.87624691110139e-06
# 50.06394525680987
# 5.87624691110139e-06
# 35.599996082502045
# [5.87624691110139e-06, 35.599996082502045]
# calculate
# 89
# 50.629621585932945
# 35.99999603476787
# 5.947848181243905e-06
# 50.629621585932945
# 5.947848181243905e-06
# 35.99999603476787
# [5.947848181243905e-06, 35.99999603476787]
# calculate
# 90
# 51.19529811230181
# 36.39999598702443
# 6.01946333623054e-06
# 51.19529811230181
# 6.01946333623054e-06
# 36.39999598702443
# [6.01946333623054e-06, 36.39999598702443]
# calculate
# 91
# 51.76097482944925
# 36.799995939271945
# 6.091092070089556e-06
# 51.76097482944925
# 6.091092070089556e-06
# 36.799995939271945
# [6.091092070089556e-06, 36.799995939271945]
# calculate
# 92
# 52.32665173118769
# 37.1999958915106
# 6.16273408685244e-06
# 52.32665173118769
# 6.16273408685244e-06
# 37.1999958915106
# [6.16273408685244e-06, 37.1999958915106]
# calculate
# 93
# 52.89232881159427
# 37.599995843740594
# 6.23438910012257e-06
# 52.89232881159427
# 6.23438910012257e-06
# 37.599995843740594
# [6.23438910012257e-06, 37.599995843740594]
# calculate
# 94
# 53.45800606499682
# 37.9999957959621
# 6.3060568326668756e-06
# 53.45800606499682
# 6.3060568326668756e-06
# 37.9999957959621
# [6.3060568326668756e-06, 37.9999957959621]
# calculate
# 95
# 54.02368348596076
# 38.399995748175314
# 6.377737016029047e-06
# 54.02368348596076
# 6.377737016029047e-06
# 38.399995748175314
# [6.377737016029047e-06, 38.399995748175314]
# repainting
# calculate
# 96
# 54.58936106927678
# 38.7999957003804
# 6.449429390162936e-06
# 54.58936106927678
# 6.449429390162936e-06
# 38.7999957003804
# [6.449429390162936e-06, 38.7999957003804]
# calculate
# 97
# 55.155038809949275
# 39.19999565257753
# 6.521133703084899e-06
# 55.155038809949275
# 6.521133703084899e-06
# 39.19999565257753
# [6.521133703084899e-06, 39.19999565257753]
# calculate
# 98
# 55.72071670318548
# 39.59999560476685
# 6.592849710543924e-06
# 55.72071670318548
# 6.592849710543924e-06
# 39.59999560476685
# [6.592849710543924e-06, 39.59999560476685]
# calculate
# 99
# 56.28639474438535
# 39.99999555694854
# 6.664577175708449e-06
# 56.28639474438535
# 6.664577175708449e-06
# 39.99999555694854
# [6.664577175708449e-06, 39.99999555694854]
# calculate
# 100
# 56.85207292913191
# 40.399995509122746
# 6.736315868868886e-06
# 56.85207292913191
# 6.736315868868886e-06
# 40.399995509122746
# [6.736315868868886e-06, 40.399995509122746]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Python\lib\site-packages\IPython\core\interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
